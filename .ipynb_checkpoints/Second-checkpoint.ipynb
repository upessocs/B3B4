# %%
# id type

a = 1

# %%
print(a)
print(id(a))
print(type(a))
# Out:
# 1
# 140586771751048
# <class 'int'>

# %%
a = "2.2"

# %%
print(a)
print(id(a))
print(type(a))
# Out:
# 2
# 140586771751080
# <class 'int'>

# %%
print(a)
print(id(a))
print(type(a))
# Out:
# 2.2
# 140586712142448
# <class 'float'>

# %%
a=10
b=10

# %%
print(a)
print(id(a))
print(type(a))
# Out:
# 2.2
# 140586568017264
# <class 'str'>

# %%
list1 = [1, 2, 3]

# %%
print(list1)
# Out:
# [1, 2, 3]

# %%
# Out:
# <class 'list'>
# 140586568080192

# %%
list1.append(6)
print(list1)
print(type(list1))
print(id(list1))
# Out:
# [1, 2, 3, 6]
# <class 'list'>
# 140586568080192

# %%
""" multiline comment 
second line 


"""

'''

this is also comment
'''


a=10
b=2
# print larger number of a and b
if a>b:
    print("a is larger than b")
    # this condition fails
    # print(a)
    print(b)



else:
    print("a is smaller than b")

print(id(a))
# Out:
# a is larger than b
# 2
# 140586771751336

# %%
a>b
# Out:
# False

# %%
# strings

str1 = r"this is \"test\" string"
str2 = r'This is \second test string'
print(str1)
# Out:
# this is \"test\" string

# %%
str1=str1.upper()
# print()
print(str1)
# Out:
# THIS IS \"TEST\" STRING

# %%
str2.replace("second,"2")
# Out:
# 'This is \\2 test string'

# %%
str1="hello"
str2="python"

str1 + " " + str2
# Out:
# 'hello python'

# %%
str1 * 4
# Out:
# 'hellohellohellohello'

# %%
print("test" in str1)
# Out:
# True

# %%
str1
# Out:
# 'this is \\"test\\" string'

# %%
str1[0:5]
# Out:
# 'this '

# %%
numbersstr = "0123456789"

# %%
numbersstr[0:10]
# Out:
# '0123456789'

# %%
len(numbersstr)
# Out:
# 10

# %%
numbersstr[-2]
# Out:
# '8'

# %%
name="raj"
fav="python, javascript"

# My name is prateek and i like python

print("My name is "+ name + " and i like " + fav)
# Out:
# My name is raj and i like python, javascript

# %%
strPlaceholders="My name is {} and I am {} years old."
print(strPlaceholders)
# Out:
# My name is {} and I am {} years old.

# %%
strPlaceholders.format(fav,nam
# Out:
# 'My name is python, javascript and I am raj years old.'

# %%
fstr=f"My name is { name } and I am { fav } years old."
print(fstr)
# Out:
# My name is raj and I am python, javascript years old.

# %%
100*10
# Out:
# 1000

# %%
1075//10
# Out:
# 107

# %%
10**3
# Out:
# 1000

# %%
pow(10,3)
# Out:
# 1000

# %%
a=(1,234,23,345,3466, 0,-1) #tuple

# %%
min(a)
# Out:
# -1

# %%
max(a)
# Out:
# 3466

# %%
sum(a)
# Out:
# 4068

# %%
val=input("Enter your batchno")
print(f"HI {val}")
# Out:
# Enter your batchno 1
# HI 1

# %%
a=1
b=-1.6
c=str(a+b)
c
# Out:
# '-0.6000000000000001'
